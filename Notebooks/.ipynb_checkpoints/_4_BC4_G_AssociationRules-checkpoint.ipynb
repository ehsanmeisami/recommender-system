# %% [markdown]
# # Note: This notebook is just a supplement and plays a subordinate role!

# %% [markdown]
# # Market Basket Analysis

# %%
# conventional libraries
import os
import calendar
import pandas as pd
import numpy as np

# data visualizations
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode,iplot
import seaborn as sns
import matplotlib.pyplot as plt

# algorithm
from scipy.sparse import coo_matrix
from implicit.als import AlternatingLeastSquares
from implicit.evaluation import ranking_metrics_at_k
from tqdm import tqdm

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("df_cleaned.csv")
#from https://www.kaggle.com/abdulmeral/rfm-analysis-for-successful-customer-segmentation

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
data_apriori = df[df['Country']=='United Kingdom']
data_apriori.head()
# Out:
#    InvoiceNo StockCode                          Description  SC_Clean  \
# 0     536365    85123A   white hanging heart t-light holder      3716
# 1     536365     71053                  white metal lantern      3724
# 2     536365    84406B       cream cupid hearts coat hanger       861
# 3     536365    84029G  knitted union flag hot water bottle      1813
# 4     536365    84029E       red woolly hottie white heart.      2776
#
#    Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 0         6  2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1         6  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2         8  2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3         6  2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4         6  2010-12-01 08:26:00       3.39       17850  United Kingdom
#
#   StockCode_NR  ... Week  Year_Month  Hour  weekday_nr  Day  is_cancelled  \
# 0        85123  ...   48     2010-12     8           3    1             0
# 1        71053  ...   48     2010-12     8           3    1             0
# 2        84406  ...   48     2010-12     8           3    1             0
# 3        84029  ...   48     2010-12     8           3    1             0
# 4        84029  ...   48     2010-12     8           3    1             0
#
#      weekday  Quarter                 Date  RefundFlg
# 0  Wednesday       Q3  2010-12-01 00:00:00      False
# 1  Wednesday       Q3  2010-12-01 00:00:00      False
# 2  Wednesday       Q3  2010-12-01 00:00:00      False
# 3  Wednesday       Q3  2010-12-01 00:00:00      False
# 4  Wednesday       Q3  2010-12-01 00:00:00      False
#
# [5 rows x 27 columns]

# %%
# Which Product and Their Count 
data_apr = data_apriori.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
data_apr.head()
# Out:
# Description   4 purple flock dinner candles   50's christmas gift bag large  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
#
# Description   dolly girl beaker   i love london mini backpack  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
# 536368                      0.0                           0.0
# 536369                      0.0                           0.0
#
# Description   nine drawer office tidy   oval wall mirror diamante   \
# InvoiceNo
# 536365                            0.0                          0.0
# 536366                            0.0                          0.0
# 536367                            0.0                          0.0
# 536368                            0.0                          0.0
# 536369                            0.0                          0.0
#
# Description   red spot gift bag large   set 2 tea towels i love london   \
# InvoiceNo
# 536365                            0.0                               0.0
# 536366                            0.0                               0.0
# 536367                            0.0                               0.0
# 536368                            0.0                               0.0
# 536369                            0.0                               0.0
#
# Description   spaceboy baby gift set   toadstool bedside light   ...  \
# InvoiceNo                                                        ...
# 536365                           0.0                        0.0  ...
# 536366                           0.0                        0.0  ...
# 536367                           0.0                        0.0  ...
# 536368                           0.0                        0.0  ...
# 536369                           0.0                        0.0  ...
#
# Description  zinc star t-light holder   zinc sweetheart soap dish  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
#
# Description  zinc sweetheart wire letter rack  zinc t-light holder star large  \
# InvoiceNo
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
# 536368                                    0.0                             0.0
# 536369                                    0.0                             0.0
#
# Description  zinc t-light holder stars large  zinc t-light holder stars small  \
# InvoiceNo
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
# 536368                                   0.0                              0.0
# 536369                                   0.0                              0.0
#
# Description  zinc top  2 door wooden shelf   zinc willie winkie  candle stick  \
# InvoiceNo
# 536365                                  0.0                               0.0
# 536366                                  0.0                               0.0
# 536367                                  0.0                               0.0
# 536368                                  0.0                               0.0
# 536369                                  0.0                               0.0
#
# Description  zinc wire kitchen organiser  zinc wire sweetheart letter tray
# InvoiceNo
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
# 536368                               0.0                               0.0
# 536369                               0.0                               0.0
#
# [5 rows x 3838 columns]

# %%
basket_new = data_apr.applymap(lambda x: 1 if x>0 else 0)
basket_new.head()
# Out:
# Description   4 purple flock dinner candles   50's christmas gift bag large  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
#
# Description   dolly girl beaker   i love london mini backpack  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
#
# Description   nine drawer office tidy   oval wall mirror diamante   \
# InvoiceNo
# 536365                              0                            0
# 536366                              0                            0
# 536367                              0                            0
# 536368                              0                            0
# 536369                              0                            0
#
# Description   red spot gift bag large   set 2 tea towels i love london   \
# InvoiceNo
# 536365                              0                                 0
# 536366                              0                                 0
# 536367                              0                                 0
# 536368                              0                                 0
# 536369                              0                                 0
#
# Description   spaceboy baby gift set   toadstool bedside light   ...  \
# InvoiceNo                                                        ...
# 536365                             0                          0  ...
# 536366                             0                          0  ...
# 536367                             0                          0  ...
# 536368                             0                          0  ...
# 536369                             0                          0  ...
#
# Description  zinc star t-light holder   zinc sweetheart soap dish  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
#
# Description  zinc sweetheart wire letter rack  zinc t-light holder star large  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
#
# Description  zinc t-light holder stars large  zinc t-light holder stars small  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
#
# Description  zinc top  2 door wooden shelf   zinc willie winkie  candle stick  \
# InvoiceNo
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536369                                    0                                 0
#
# Description  zinc wire kitchen organiser  zinc wire sweetheart letter tray
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
#
# [5 rows x 3838 columns]

# %%
basket_new.iloc[0].value_counts()
# Out:
# 0    3831
# 1       7
# Name: 536365, dtype: int64

# %%
itemsets = apriori(basket_new, min_support=0.02, use_colnames=True)

# %%
itemsets.sort_values('support',ascending=False).head()
# Out:
#       support                              itemsets
# 187  0.113658  (white hanging heart t-light holder)
# 81   0.087295             (jumbo bag red retrospot)
# 152  0.085063            (regency cakestand 3 tier)
# 11   0.078427       (assorted colour bird ornament)
# 126  0.077823                       (party bunting)

# %%
rules = association_rules(itemsets, metric="lift", min_threshold=1)
rules.shape
# Out:
# (76, 9)

# %%
sns.scatterplot(x='support', y='confidence', hue='lift', data=rules)
plt.show()

# %%
sns.scatterplot(x='support', y='confidence', hue='leverage', data=rules)
plt.show()

# %%
rules.sort_values(['support', 'lift'], ascending=False).head(10)
# Out:
#                              antecedents  \
# 12             (jumbo bag red retrospot)
# 13             (jumbo bag pink polkadot)
# 26             (lunch bag  black skull.)
# 27             (lunch bag red retrospot)
# 6     (roses regency teacup and saucer )
# 7      (green regency teacup and saucer)
# 42             (lunch bag pink polkadot)
# 43             (lunch bag red retrospot)
# 2    (gardeners kneeling pad keep calm )
# 3   (gardeners kneeling pad cup of tea )
#
#                              consequents  antecedent support  \
# 12             (jumbo bag pink polkadot)            0.087295
# 13             (jumbo bag red retrospot)            0.048986
# 26             (lunch bag red retrospot)            0.060087
# 27             (lunch bag  black skull.)            0.067568
# 6      (green regency teacup and saucer)            0.040903
# 7     (roses regency teacup and saucer )            0.036921
# 42             (lunch bag red retrospot)            0.051158
# 43             (lunch bag pink polkadot)            0.067568
# 2   (gardeners kneeling pad cup of tea )            0.044764
# 3    (gardeners kneeling pad keep calm )            0.037826
#
#     consequent support   support  confidence       lift  leverage  conviction
# 12            0.048986  0.030526    0.349689   7.138479  0.026250    1.462398
# 13            0.087295  0.030526    0.623153   7.138479  0.026250    2.421950
# 26            0.067568  0.029199    0.485944   7.191968  0.025139    1.813872
# 27            0.060087  0.029199    0.432143   7.191968  0.025139    1.655193
# 6             0.036921  0.028716    0.702065  19.015405  0.027206    3.232513
# 7             0.040903  0.028716    0.777778  19.015405  0.027206    4.315939
# 42            0.067568  0.028415    0.555425   8.220283  0.024958    2.097355
# 43            0.051158  0.028415    0.420536   8.220283  0.024958    1.637446
# 2             0.037826  0.027630    0.617251  16.318257  0.025937    2.513850
# 3             0.044764  0.027630    0.730463  16.318257  0.025937    3.543984

# %%
from mlxtend.frequent_patterns import fpgrowth
rule_fp = fpgrowth(basket_new, min_support=0.02, use_colnames=True)
rule_fp
# Out:
#       support                                           itemsets
# 0    0.113658               (white hanging heart t-light holder)
# 1    0.026424                           (hand warmer union jack)
# 2    0.078427                    (assorted colour bird ornament)
# 3    0.039998                         (home building block word)
# 4    0.032215                         (love building block word)
# ..        ...                                                ...
# 233  0.020089  (lunch bag suki design , lunch bag pink polkadot)
# 234  0.023709  (lunch bag suki design , lunch bag  black skull.)
# 235  0.020089  (lunch bag apple design, lunch bag red retrospot)
# 236  0.021658                    (party bunting, spotty bunting)
# 237  0.027630  (gardeners kneeling pad keep calm , gardeners ...
#
# [238 rows x 2 columns]

# %%
items = apriori(basket_new, min_support=0.02, use_colnames=True)
items
# Out:
#       support                                           itemsets
# 0    0.022502                         (3 stripey mice feltcraft)
# 1    0.037886                           (6 ribbons rustic charm)
# 2    0.025881                  (60 cake cases vintage christmas)
# 3    0.035413                      (60 teatime fairy cake cases)
# 4    0.026786                   (72 sweetheart fairy cake cases)
# ..        ...                                                ...
# 233  0.023106  (pink regency teacup and saucer, roses regency...
# 234  0.025820  (red hanging heart t-light holder, white hangi...
# 235  0.021236  (roses regency teacup and saucer , regency cak...
# 236  0.027630  (wooden frame antique white , wooden picture f...
# 237  0.020572  (pink regency teacup and saucer, roses regency...
#
# [238 rows x 2 columns]

# %%
rule = association_rules(items, metric="lift", min_threshold=1)
rule
# Out:
#                                           antecedents  \
# 0                         (alarm clock bakelike red )
# 1                        (alarm clock bakelike green)
# 2                 (gardeners kneeling pad keep calm )
# 3                (gardeners kneeling pad cup of tea )
# 4                    (pink regency teacup and saucer)
# ..                                                ...
# 71  (pink regency teacup and saucer, green regency...
# 72  (roses regency teacup and saucer , green regen...
# 73                   (pink regency teacup and saucer)
# 74                 (roses regency teacup and saucer )
# 75                  (green regency teacup and saucer)
#
#                                           consequents  antecedent support  \
# 0                        (alarm clock bakelike green)            0.045729
# 1                         (alarm clock bakelike red )            0.041626
# 2                (gardeners kneeling pad cup of tea )            0.044764
# 3                 (gardeners kneeling pad keep calm )            0.037826
# 4                   (green regency teacup and saucer)            0.029742
# ..                                                ...                 ...
# 71                 (roses regency teacup and saucer )            0.024373
# 72                   (pink regency teacup and saucer)            0.028716
# 73  (roses regency teacup and saucer , green regen...            0.029742
# 74  (pink regency teacup and saucer, green regency...            0.040903
# 75  (pink regency teacup and saucer, roses regency...            0.036921
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.041626  0.027389    0.598945  14.388559  0.025485    2.389629
# 1             0.045729  0.027389    0.657971  14.388559  0.025485    2.790030
# 2             0.037826  0.027630    0.617251  16.318257  0.025937    2.513850
# 3             0.044764  0.027630    0.730463  16.318257  0.025937    3.543984
# 4             0.036921  0.024373    0.819473  22.195389  0.023274    5.334809
# ..                 ...       ...         ...        ...       ...         ...
# 71            0.040903  0.020572    0.844059  20.635883  0.019575    6.150403
# 72            0.029742  0.020572    0.716387  24.086863  0.019718    3.421059
# 73            0.028716  0.020572    0.691684  24.086863  0.019718    3.150282
# 74            0.024373  0.020572    0.502950  20.635883  0.019575    1.962835
# 75            0.023106  0.020572    0.557190  24.114814  0.019719    2.206123
#
# [76 rows x 9 columns]

# %% [markdown]
# ## Beginning of MBA

# %% [markdown]
# ### Support

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% or 2.5% of the transactions (more info at http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
frequent_itemsets = apriori(basket_new, min_support=0.02, use_colnames=True)
frequent_itemsets.head()
# Out:
#     support                           itemsets
# 0  0.022502         (3 stripey mice feltcraft)
# 1  0.037886           (6 ribbons rustic charm)
# 2  0.025881  (60 cake cases vintage christmas)
# 3  0.035413      (60 teatime fairy cake cases)
# 4  0.026786   (72 sweetheart fairy cake cases)

# %% [markdown]
# ### Confidence

# %%
# Generate the association rules - by confidence
rulesConfidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.50)
rulesConfidence.sort_values(by='confidence', ascending=False, inplace=True)
rulesConfidence.head()
# Out:
#                                           antecedents  \
# 24  (pink regency teacup and saucer, roses regency...
# 25  (pink regency teacup and saucer, green regency...
# 4                    (pink regency teacup and saucer)
# 7                   (green regency teacup and saucer)
# 18                   (pink regency teacup and saucer)
#
#                            consequents  antecedent support  \
# 24   (green regency teacup and saucer)            0.023106
# 25  (roses regency teacup and saucer )            0.024373
# 4    (green regency teacup and saucer)            0.029742
# 7   (roses regency teacup and saucer )            0.036921
# 18  (roses regency teacup and saucer )            0.029742
#
#     consequent support   support  confidence       lift  leverage  conviction
# 24            0.036921  0.020572    0.890339  24.114814  0.019719    8.782365
# 25            0.040903  0.020572    0.844059  20.635883  0.019575    6.150403
# 4             0.036921  0.024373    0.819473  22.195389  0.023274    5.334809
# 7             0.040903  0.028716    0.777778  19.015405  0.027206    4.315939
# 18            0.040903  0.023106    0.776876  18.993364  0.021889    4.298501

# %% [markdown]
# ### Lift

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=1.3)
rulesLift.sort_values(by='lift', ascending=False, inplace=True)
rulesLift.head()
# Out:
#                                           antecedents  \
# 75                  (green regency teacup and saucer)
# 70  (pink regency teacup and saucer, roses regency...
# 73                   (pink regency teacup and saucer)
# 72  (roses regency teacup and saucer , green regen...
# 4                    (pink regency teacup and saucer)
#
#                                           consequents  antecedent support  \
# 75  (pink regency teacup and saucer, roses regency...            0.036921
# 70                  (green regency teacup and saucer)            0.023106
# 73  (roses regency teacup and saucer , green regen...            0.029742
# 72                   (pink regency teacup and saucer)            0.028716
# 4                   (green regency teacup and saucer)            0.029742
#
#     consequent support   support  confidence       lift  leverage  conviction
# 75            0.023106  0.020572    0.557190  24.114814  0.019719    2.206123
# 70            0.036921  0.020572    0.890339  24.114814  0.019719    8.782365
# 73            0.028716  0.020572    0.691684  24.086863  0.019718    3.150282
# 72            0.029742  0.020572    0.716387  24.086863  0.019718    3.421059
# 4             0.036921  0.024373    0.819473  22.195389  0.023274    5.334809
